# %%
import numpy as np
import pandas as pd
import gzip
import fitdecode

# %%
df = pd.read_csv('data/garmin_activities.csv')
df
# Out:
#     Aktivitetstype                 Dato  Favoritt           Tittel Avstand  \
# 0           Løping  2022-08-20 19:41:04     False      Oslo Løping   17.03
# 1    Styrketrening  2022-08-20 16:37:06     False           Styrke    0.00
# 2    Styrketrening  2022-08-19 14:50:23     False           Styrke    0.00
# 3       Terrengløp  2022-08-18 17:03:22     False  Oslo Terrengløp    9.92
# 4           Løping  2022-08-16 20:00:47     False      Oslo Løping   12.37
# ..             ...                  ...       ...              ...     ...
# 255          Gåtur  2020-12-25 13:25:18     False     Tysvær Gåing    3.02
# 256         Løping  2020-12-19 22:26:37     False      Oslo Løping    4.07
# 257         Løping  2020-12-17 07:31:00     False      Oslo Løping   13.41
# 258          Gåtur  2020-12-12 23:15:29     False       Oslo Gåing    2.02
# 259         Løping  2020-12-09 22:33:34     False      Oslo Løping    4.53
#
# ...

# %%
df = df.query("Aktivitetstype == 'Løping'")

# %%
df = df.drop(columns=['Favoritt', 'Overflateintervall', 'Dekompresjon'])

# %%
df
# Out:
#     Aktivitetstype                 Dato              Tittel Avstand Kalorier  \
# 0           Løping  2022-08-20 19:41:04         Oslo Løping   17.03    1,181
# 4           Løping  2022-08-16 20:00:47         Oslo Løping   12.37      894
# 7           Løping  2022-08-14 17:21:00         Oslo Løping    5.62      360
# 12          Løping  2022-08-11 20:51:26  Oslo Course à pied    7.10      486
# 28          Løping  2022-07-25 18:48:43  Oslo Course à pied    7.01      520
# ..             ...                  ...                 ...     ...      ...
# 252         Løping  2021-01-15 13:18:48         Oslo Løping    6.80      531
# 254         Løping  2020-12-31 16:29:19         Oslo Løping    5.74      456
# 256         Løping  2020-12-19 22:26:37         Oslo Løping    4.07      335
# 257         Løping  2020-12-17 07:31:00         Oslo Løping   13.41      995
# 259         Løping  2020-12-09 22:33:34         Oslo Løping    4.53      344
#
# ...
